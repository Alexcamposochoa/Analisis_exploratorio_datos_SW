# %% [markdown]
# # Fechas Entregas
#
# #### ·18 Octubre Miércoles tema, hipótesis y datasets.
# #### ·25 de Octubre Miércoles a las 9.00h repositorio de github.
# #### ·26 Octubre Jueves a las 09.00h archivo presentacion en classroom y presentación de 10 min meet.

# %% [markdown]
# es la más rentable? sera rapido de demostrar ingresos vs costos
# influencia social?
# critica social
# critica criticos
#
# consejos, tener temática, coger muchos datos, despues hacernos preguntas.
#
# impacto en RRSS de los actores antes o despues de una peli.
#
# puntuacion antes vs puntuacion actual.

# %% [markdown]
# buscador de google de datasets

# %% [markdown]
# estudio sobre cuanto mas se valoran las pelis ahora , especie de compensacion.
#
# calculo o relacion de la inflacion entre la inversion y presupuesto y beneficios.
#
# precio de las peliculas de cine actualmente.

# %% [markdown]
# tutoria santi:
#
# de lo general                   a                lo particular
# todo el espacio cinematografico a en concreto SW y pelis individuales

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv("data/MovieFranchises.csv")

# %%
df1 = df1.drop("index", axis=1)

# %%
df1.head()
# Out:
#   MovieID                                           Title Lifetime Gross  \
# 0    1001              Star Wars: Episode IV - A New Hope      775398007
# 1    1002  Star Wars: Episode V - The Empire Strikes Back      538375067
# 2    1003      Star Wars: Episode VI - Return of the Jedi      475106177
# 3    1004                                   Jurassic Park     1109802321
# 4    1005                   The Lost World: Jurassic Park      618638999
#
#    Year              Studio Rating  Runtime      Budget ReleaseDate  VoteAvg  \
# 0  1977           Lucasfilm     PG    121.0  11000000.0    05-25-77     4.09
# 1  1980           Lucasfilm     PG    124.0  18000000.0    06-20-80     4.12
# 2  1983           Lucasfilm     PG    135.0  32500000.0    05-25-83     3.98
# 3  1993  Universal Pictures  PG-13    127.0  63000000.0    06-11-93     3.69
# 4  1997  Universal Pictures  PG-13    129.0  73000000.0    05-23-97     3.01
#
#    VoteCount  FranchiseID
# 0    96233.0        101.0
# ...

# %%
df1.rename(columns={"Title":"Nombre","Lifetime Gross":"Recaudacion","Year":"Año","Studio":"Estudio","Runtime":"Duracion","Budget":"Presupuesto","ReleaseDate":"Fecha Lanzamiento"}, inplace=True)

# %%
df1.head()
# Out:
#   MovieID                                          Nombre Recaudacion   Año  \
# 0    1001              Star Wars: Episode IV - A New Hope   775398007  1977
# 1    1002  Star Wars: Episode V - The Empire Strikes Back   538375067  1980
# 2    1003      Star Wars: Episode VI - Return of the Jedi   475106177  1983
# 3    1004                                   Jurassic Park  1109802321  1993
# 4    1005                   The Lost World: Jurassic Park   618638999  1997
#
#               Estudio Rating  Duracion  Presupuesto Fecha Lanzamiento  \
# 0           Lucasfilm     PG     121.0   11000000.0          05-25-77
# 1           Lucasfilm     PG     124.0   18000000.0          06-20-80
# 2           Lucasfilm     PG     135.0   32500000.0          05-25-83
# 3  Universal Pictures  PG-13     127.0   63000000.0          06-11-93
# 4  Universal Pictures  PG-13     129.0   73000000.0          05-23-97
#
#    VoteAvg  VoteCount  FranchiseID
# 0     4.09    96233.0        101.0
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 605 entries, 0 to 604
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   MovieID            605 non-null    object
#  1   Nombre             605 non-null    object
#  2   Recaudacion        605 non-null    object
#  3   Año                66 non-null     object
#  4   Estudio            60 non-null     object
#  5   Rating             60 non-null     object
#  6   Duracion           60 non-null     float64
#  7   Presupuesto        60 non-null     float64
#  8   Fecha Lanzamiento  60 non-null     object
#  9   VoteAvg            60 non-null     float64
#  10  VoteCount          60 non-null     float64
#  11  FranchiseID        60 non-null     float64
# dtypes: float64(5), object(7)
# memory usage: 56.8+ KB

# %%
df1.tail(60)
# Out:
#          MovieID           Nombre Recaudacion               Año Estudio  \
# 545         1128             1043     Fantasy               NaN     NaN
# 546         1129             1043      Comedy               NaN     NaN
# 547         1130             1044   Adventure               NaN     NaN
# 548         1131             1044      Sci-Fi               NaN     NaN
# 549         1132             1044      Action               NaN     NaN
# 550         1133             1045      Action               NaN     NaN
# 551         1134             1045   Adventure               NaN     NaN
# 552         1135             1045      Sci-Fi               NaN     NaN
# 553         1136             1046   Adventure               NaN     NaN
# 554         1137             1046      Sci-Fi               NaN     NaN
# 555         1138             1046      Action               NaN     NaN
# 556         1139             1047      Action               NaN     NaN
# ...

# %%
# Vamos a buscar el ejercicio donde limpiamos nulos en funcion a un porcentaje. , la columna recaudacion deberia ser un float y es un object, tenemos que trabajar con ella

# %%
df1.describe()
# Out:
#          Duracion   Presupuesto    VoteAvg     VoteCount  FranchiseID
# count   60.000000  6.000000e+01  60.000000     60.000000    60.000000
# mean   137.983333  1.752417e+08   3.556000  21722.266667   103.600000
# std     19.022281  7.568151e+07   0.361359  23551.977668     1.596607
# min     92.000000  1.100000e+07   2.640000    238.000000   101.000000
# 25%    125.500000  1.287500e+08   3.305000   8186.250000   102.000000
# 50%    135.000000  1.700000e+08   3.645000  13226.500000   104.000000
# 75%    147.000000  2.050000e+08   3.822500  26603.750000   105.000000
# max    201.000000  4.000000e+08   4.120000  96233.000000   105.000000

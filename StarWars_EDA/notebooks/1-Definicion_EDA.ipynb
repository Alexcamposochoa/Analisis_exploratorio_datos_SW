# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# # Star Wars.
# ## La franquicia más rentable de la historia del cine
# ###### Spoiler : o no

# %% [markdown]
# ### TEMA

# %% [markdown]
# Puntos clave:
#
# ## 1. Rentabilidad de Star Wars vs el resto de franquicias :
#
# Vamos a usar diferentes datasets para calcular la rentabilidad, considerando ingresos, presupuestos y rating de las películas, para así determinar si Star Wars es la franquicia más rentable de la historia del cine o no.
#
# ## 2. Comparación de otros factores respecto a otras franquicias:
#
# Compararemos y evaluaremos la posición de Star Wars frente a otras de las franquicias populares que determinaremos durante el proyecto y destacaremos virtudes y defectos de unas vs otras.
#
# ## 3. Análisis social y económico:
#
# Trataremos de encontrar insights respecto al impacto social tanto en actores como en el publico en general, como a nivel economico de la pelicula, teniendo en cuenta datos como la inflacion de los años 80 respecto a la actual.
#
# ## 4. Maybe Bonus Track. WebS craping:
#
# Como hipotético aporte final trataremos de webscrapear algunas de las tiendas mas importantes de ventas de merchandising para tratar de relacionar el exito/popularidad con la cantidad de articulos y/o su precio u otros insights que nos encontremos.

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# #### · Es Star Wars la franquicia mas rentable de la historia?
# #### · Que factores influyeron en el exito de StarWars? y sus principales competidoras?
# #### · Que valora la gente de una pelicula?y por genero?
# #### · Si Star Wars se rodase este año con el mismo presupuesto que conseguirian? Cuanto ganarían? Tendría el mismo exito? (me tiro el pisto jaja)

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
import pandas as pd

# %%
df_1 = pd.read_csv("data/MovieFranchises.csv")
fuente = "https://www.kaggle.com/datasets/thedevastator/global-movie-franchise-revenue-and-budget-data"

# %%
df_1.head(10)
# Out:
#    index MovieID                                              Title  \
# 0      0    1001                 Star Wars: Episode IV - A New Hope
# 1      1    1002     Star Wars: Episode V - The Empire Strikes Back
# 2      2    1003         Star Wars: Episode VI - Return of the Jedi
# 3      3    1004                                      Jurassic Park
# 4      4    1005                      The Lost World: Jurassic Park
# 5      5    1006          Star Wars: Episode I - The Phantom Menace
# 6      6    1007                                  Jurassic Park III
# 7      7    1008              Harry Potter and the Sorcerer's Stone
# 8      8    1009  The Lord of the Rings: The Fellowship of the Ring
# 9      9    1010       Star Wars: Episode II - Attack of the Clones
#
#   Lifetime Gross  Year              Studio Rating  Runtime       Budget  \
# 0      775398007  1977           Lucasfilm     PG    121.0   11000000.0
# 1      538375067  1980           Lucasfilm     PG    124.0   18000000.0
# ...

# %%
#En un primer vistazo vemos que este data set de tan solo 605 filas, está más centrado en peliculas que pertenecen a franquicias cinematográficas.

# %%
print(df_1.shape)
print("-"*50)
print(df_1.info())
df_1.describe()
# Out:
# (605, 13)
# --------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 605 entries, 0 to 604
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           605 non-null    int64
#  1   MovieID         605 non-null    object
#  2   Title           605 non-null    object
#  3   Lifetime Gross  605 non-null    object
#  4   Year            66 non-null     object
#  5   Studio          60 non-null     object
#  6   Rating          60 non-null     object
#  7   Runtime         60 non-null     float64
#  8   Budget          60 non-null     float64
#  9   ReleaseDate     60 non-null     object
#  10  VoteAvg         60 non-null     float64
#  11  VoteCount       60 non-null     float64
#  12  FranchiseID     60 non-null     float64
# dtypes: float64(5), int64(1), object(7)
# memory usage: 61.6+ KB
# None
# ...

# %%
df_2 = pd.read_csv("data/mcu_dataset.csv")
fuente = "looking for"

# %%
df_2.head()
# Out:
#                                  Name US release Date         Director  \
# 0                            Iron Man     May 2, 2008      Jon Favreau
# 1                 The incredible Hulk   June 13, 2008  Louis Leterrier
# 2                          Iron Man 2     May 7, 2010      Jon Favreau
# 3                                Thor     May 6, 2011  Kenneth Branagh
# 4  Captain America: The first Avenger   July 22, 2011     Joe Jhonston
#
#                                   Producer  Duration  \
# 0                 Avi Arad and Kevin Feige   2h 6min
# 1  Avi Arad ,Gale Ann Hurd and Kevin Feige  1h 52min
# 2                              Kevin Feige   2h 4min
# 3                              Kevin Feige  1h 55min
# 4                              Kevin Feige   2h 4min
#
#                          Genre  IMDB rating  metascore  \
# 0   Action , Adventure, Sci-Fi          7.9         79
# 1   Action , Adventure, Sci-Fi          6.6         61
# ...

# %%
#Un data set propio de MCU con datos numéricos interesantes

# %%
print(df_2.shape)
print("-"*50)
print(df_2.info())
df_2.describe()
# Out:
# (23, 16)
# --------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              23 non-null     object
#  1   US release Date   23 non-null     object
#  2   Director          23 non-null     object
#  3   Producer          23 non-null     object
#  4   Duration          23 non-null     object
#  5   Genre             23 non-null     object
#  6   IMDB rating       23 non-null     float64
#  7   metascore         23 non-null     int64
#  8   Cast              23 non-null     object
#  9   Budget            23 non-null     object
#  10  Domestic Gross    23 non-null     object
#  11  Total Gross       23 non-null     object
#  12  Opening Gross     23 non-null     object
#  13  Oscar Nomination  23 non-null     int64
#  14  Oscar won         23 non-null     int64
# ...

# %%
df_3 = pd.read_csv("data/Movies_Cleaned.csv")
fuente = "https://data.world/priyankad0993/sequels/workspace/file?filename=Movies+-+Cleaned.xlsx"

# %%
df_3.head()
# Out:
#    index                  Title Release Date    Year  Description  \
# 0      0         101 Dalmatians   18-11-1996  1996.0          NaN
# 1      1         102 Dalmatians   22-11-2000  2000.0          NaN
# 2      2              12 Rounds   19-03-2009  2009.0          NaN
# 3      3  12 Rounds 2: Reloaded   04-06-2013  2013.0          NaN
# 4      4         21 Jump Street   12-03-2012  2012.0          NaN
#
#                                      URL  IMDb Rating  Runtime (mins)  \
# 0  https://www.imdb.com/title/tt0115433/          5.7           103.0
# 1  https://www.imdb.com/title/tt0211181/          4.9           100.0
# 2  https://www.imdb.com/title/tt1160368/          5.6           108.0
# 3  https://www.imdb.com/title/tt2317524/          5.3            95.0
# 4  https://www.imdb.com/title/tt1232829/          7.2           109.0
#
#                              Genres  Num Votes                      Directors  \
# ...

# %%
#Data set de peliculas que como aspectos diferenciales nos ofrece la columna del rating, el numero de votos y además del nombre de la "serie de peliculas" a la que pertenece
#y su lugar en la serie.

# %%
print(df_3.shape)
print("-"*50)
print(df_3.info())
df_3.describe()
# Out:
# (866, 13)
# --------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 866 entries, 0 to 865
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           866 non-null    int64
#  1   Title           866 non-null    object
#  2   Release Date    853 non-null    object
#  3   Year            854 non-null    float64
#  4   Description     0 non-null      float64
#  5   URL             866 non-null    object
#  6   IMDb Rating     847 non-null    float64
#  7   Runtime (mins)  847 non-null    float64
#  8   Genres          866 non-null    object
#  9   Num Votes       847 non-null    float64
#  10  Directors       858 non-null    object
#  11  Movie Series    866 non-null    object
#  12  Order           866 non-null    int64
# dtypes: float64(5), int64(2), object(6)
# memory usage: 88.1+ KB
# None
# ...

# %%
df_4 = pd.read_csv("data/Movies_with_sequels.csv")
fuente = "https://data.world/priyankad0993/sequels/workspace/file?filename=Movies+with+sequels.csv"

# %%
df_4.head()
# Out:
#    index  Position      Const     Created    Modified  Description  \
# 0      0         1  tt0145487  03-11-2011  03-11-2011          NaN
# 1      1         2  tt0316654  03-11-2011  03-11-2011          NaN
# 2      2         3  tt0413300  03-11-2011  03-11-2011          NaN
# 3      3         4  tt0133093  03-11-2011  03-11-2011          NaN
# 4      4         5  tt0234215  03-11-2011  03-11-2011          NaN
#
#                  Title                                    URL Title Type  \
# 0           Spider-Man  https://www.imdb.com/title/tt0145487/      movie
# 1         Spider-Man 2  https://www.imdb.com/title/tt0316654/      movie
# 2         Spider-Man 3  https://www.imdb.com/title/tt0413300/      movie
# 3           The Matrix  https://www.imdb.com/title/tt0133093/      movie
# 4  The Matrix Reloaded  https://www.imdb.com/title/tt0234215/      movie
#
#    IMDb Rating  Runtime (mins)    Year                     Genres  Num Votes  \
# ...

# %%
#En teoria tenemos un dataset donde encontraremos peliculas que han tenido secuelas. Con esto trataremos de añadir al Lifetime Gross peliculas que coincidan con las franquicias
#coincidentes y tratar de encontrar otros insights.

# %%
print(df_4.shape)
print("-"*50)
print(df_4.info())
df_4.describe()
# Out:
# (1074, 16)
# --------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           1074 non-null   int64
#  1   Position        1074 non-null   int64
#  2   Const           1074 non-null   object
#  3   Created         1074 non-null   object
#  4   Modified        1074 non-null   object
#  5   Description     0 non-null      float64
#  6   Title           1074 non-null   object
#  7   URL             1074 non-null   object
#  8   Title Type      1074 non-null   object
#  9   IMDb Rating     1053 non-null   float64
#  10  Runtime (mins)  1053 non-null   float64
#  11  Year            1061 non-null   float64
#  12  Genres          1074 non-null   object
#  13  Num Votes       1053 non-null   float64
#  14  Release Date    1060 non-null   object
# ...

# %%
df_5 = pd.read_csv("data/sw3.csv")
fuente = "desconocida O.o"

# %%
df_5.head()
# Out:
#    Year                                           Title Rated Released  \
# 0  1977              Star Wars: Episode IV - A New Hope    PG  5/25/77
# 1  1980  Star Wars: Episode V - The Empire Strikes Back    PG  6/20/80
# 2  1983      Star Wars: Episode VI - Return of the Jedi    PG  5/25/83
# 3  1999       Star Wars: Episode I - The Phantom Menace    PG  5/19/99
# 4  2002    Star Wars: Episode II - Attack of the Clones    PG  5/16/02
#
#    Runtime                               Genre          Director  \
# 0  121 min  Action, Adventure, Fantasy, Sci-Fi      George Lucas
# 1  124 min  Action, Adventure, Fantasy, Sci-Fi    Irvin Kershner
# 2  131 min  Action, Adventure, Fantasy, Sci-Fi  Richard Marquand
# 3  136 min  Action, Adventure, Fantasy, Sci-Fi      George Lucas
# 4  142 min  Action, Adventure, Fantasy, Sci-Fi      George Lucas
#
#                                               Writer  \
# 0                                       George Lucas
# ...

# %%
# Dataset puro de las peliculas de StarWars

# %%
print(df_5.shape)
print("-"*50)
print(df_5.info())
df_5.describe()
# Out:
# (9, 14)
# --------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               9 non-null      int64
#  1   Title              9 non-null      object
#  2   Rated              9 non-null      object
#  3   Released           9 non-null      object
#  4   Runtime            9 non-null      object
#  5   Genre              9 non-null      object
#  6   Director           9 non-null      object
#  7   Writer             9 non-null      object
#  8   Actors             9 non-null      object
#  9   Awards             9 non-null      object
#  10  Metascore          9 non-null      int64
#  11  imdbVotes          9 non-null      int64
#  12  imdbRating         9 non-null      float64
#  13  RottenTomatoScore  9 non-null      float64
# dtypes: float64(2), int64(3), object(9)
# ...

# %%
df_6 = pd.read_csv("data/tmdb_5000_movies.csv")

# %%
df_6.head(3)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
# ...

# %%
# Dataset que forma parte de un conjunto de datasets que iban juntos, es enorme y contiene información interesante como un indice de popularidad, pais en el que fue producida o
#la ganancia directa entre otras cosas.

# %%
print(df_6.shape)
print("-"*50)
print(df_6.info())
df_6.describe()
# Out:
# (4803, 20)
# --------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
# ...
